# %%
import MultiviewGNN
MultiviewGNN.main()
# Out:
# Random seed set to: 777
# 데이터 로딩 중...
# 피처 전처리 중...
# 피처 데이터: (2480, 1385), 레이블 데이터: (496,)
#
# 원래 훈련 데이터로 교차 검증 시작...
#
# === Fold 1/5 ===
# /opt/miniconda3/envs/cmse830/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch: 001, Loss: 1.9963, Train: 0.2236, Val: 0.1400
# Epoch: 021, Loss: 0.0205, Train: 0.9888, Val: 0.8400
# Epoch: 041, Loss: 0.0024, Train: 1.0000, Val: 0.8500
# Epoch: 061, Loss: 0.0014, Train: 1.0000, Val: 0.8400
# Early stopping at epoch 72
# Fold 1 검증 정확도: 0.8500
#
# === Fold 2/5 ===
# Epoch: 001, Loss: 2.0039, Train: 0.1677, Val: 0.1010
# Epoch: 021, Loss: 0.0154, Train: 0.9975, Val: 0.8182
# Epoch: 041, Loss: 0.0025, Train: 1.0000, Val: 0.8485
# Epoch: 061, Loss: 0.0009, Train: 1.0000, Val: 0.8081
# Early stopping at epoch 74
# Fold 2 검증 정확도: 0.8586
#
# === Fold 3/5 ===
# Epoch: 001, Loss: 2.0909, Train: 0.2832, Val: 0.1414
# ...
